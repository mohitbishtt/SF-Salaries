# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Salaries.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148049 non-null object
# OvertimePay         148654 non-null object
# OtherPay            148654 non-null object
# Benefits            112495 non-null object
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              38119 non-null object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
data.drop(['Notes'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#   BasePay OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 0  167411           0   400184      NaN  567595.43         567595.43  2011
# 1  155966      245132   137811      NaN  538909.28         538909.28  2011
# 2  212739      106088  16452.6      NaN  335279.91         335279.91  2011
# 3   77916     56120.7   198307      NaN  332343.61         332343.61  2011
# 4  134402        9737   182235      NaN  326373.19         326373.19  2011
#
#           Agency Status
# 0  San Francisco    NaN
# 1  San Francisco    NaN
# 2  San Francisco    NaN
# 3  San Francisco    NaN
# 4  San Francisco    NaN

# %%
data.set_index('Id')
# Out:
#                   EmployeeName  \
# Id
# 1               NATHANIEL FORD
# 2                 GARY JIMENEZ
# 3               ALBERT PARDINI
# 4            CHRISTOPHER CHONG
# 5              PATRICK GARDNER
# 6               DAVID SULLIVAN
# 7                    ALSON LEE
# 8                DAVID KUSHNER
# 9               MICHAEL MORRIS
# 10          JOANNE HAYES-WHITE
# 11               ARTHUR KENNEY
# 12            PATRICIA JACKSON
# 13           EDWARD HARRINGTON
# 14                 JOHN MARTIN
# 15              DAVID FRANKLIN
# 16             RICHARD CORRIEA
# 17                    AMY HART
# 18              SEBASTIAN WONG
# 19                  MARTY ROSS
# 20               ELLEN MOFFATT
# 21                  VENUS AZAR
# 22                JUDY MELINEK
# 23               GEORGE GARCIA
# 24               VICTOR WYRSCH
# 25             JOSEPH DRISCOLL
# 26                GREGORY SUHR
# 27                 JOHN HANLEY
# 28              RAYMOND GUZMAN
# 29              DENISE SCHMITT
# 30               MONICA FIELDS
# ...                        ...
# 148625      Lorraine Rosenthal
# 148626         Renato C Gurion
# 148627           Paulet Gaines
# 148628        Brett A Lundberg
# 148629          Mark W Mcclure
# 148630       Elizabeth Iniguez
# 148631            Randy J Keys
# 148632         Andre M Johnson
# 148633  Sharon D Owens-Webster
# 148634        Edward Ferdinand
# 148635          David M Turner
# 148636     James S Kibblewhite
# 148637           Andrew J Enzi
# 148638        Kadeshra D Green
# 148639    Lennard B Hutchinson
# 148640       Richard A Talbert
# 148641      Charlene D Mccully
# 148642   Raphael Marquis Goins
# 148643       Dominic C Marquez
# 148644              Kim Brewer
# 148645            Randy D Winn
# 148646        Carolyn A Wilson
# 148647            Not provided
# 148648          Joann Anderson
# 148649             Leon Walker
# 148650           Roy I Tillery
# 148651            Not provided
# 148652            Not provided
# 148653            Not provided
# 148654               Joe Lopez
#
#                                                 JobTitle       BasePay  \
# Id
# 1         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY        167411
# 2                        CAPTAIN III (POLICE DEPARTMENT)        155966
# 3                        CAPTAIN III (POLICE DEPARTMENT)        212739
# 4                   WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 5           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)        134402
# 6                              ASSISTANT DEPUTY CHIEF II        118602
# 7                     BATTALION CHIEF, (FIRE DEPARTMENT)         92492
# 8                         DEPUTY DIRECTOR OF INVESTMENTS        256577
# 9                     BATTALION CHIEF, (FIRE DEPARTMENT)        176933
# 10                CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)        285262
# 11      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)        194999
# 12                       CAPTAIN III (POLICE DEPARTMENT)         99722
# 13                           EXECUTIVE CONTRACT EMPLOYEE        294580
# 14                                     DEPARTMENT HEAD V        271329
# 15                    BATTALION CHIEF, (FIRE DEPARTMENT)        174873
# 16                    COMMANDER III, (POLICE DEPARTMENT)        198778
# 17                                     DEPARTMENT HEAD V        268605
# 18                 CAPTAIN, EMERGENCYCY MEDICAL SERVICES        140547
# 19                    BATTALION CHIEF, (FIRE DEPARTMENT)        168693
# 20                            ASSISTANT MEDICAL EXAMINER        257511
# 21                            ASSISTANT MEDICAL EXAMINER        257510
# 22                            ASSISTANT MEDICAL EXAMINER        257510
# 23                             CAPTAIN, FIRE SUPPRESSION        140547
# 24                    BATTALION CHIEF, (FIRE DEPARTMENT)        168693
# 25                             CAPTAIN, FIRE SUPPRESSION        140547
# 26                                       CHIEF OF POLICE        256470
# 27                             CAPTAIN, FIRE SUPPRESSION       92080.8
# 28                    BATTALION CHIEF, (FIRE DEPARTMENT)        168693
# 29                  DEPUTY CHIEF III (POLICE DEPARTMENT)        261718
# 30          DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)        246226
# ...                                                  ...           ...
# 148625                                      Senior Clerk          0.00
# 148626                                  Registered Nurse          0.00
# 148627                                     Account Clerk          0.00
# 148628                                   General Laborer          0.00
# 148629                                   General Laborer          0.00
# 148630                                Transcriber Typist          0.00
# 148631                                         Carpenter          0.00
# 148632                       Communications Dispatcher 1          0.00
# 148633                        Protective Services Worker          0.00
# 148634                                   General Laborer          0.00
# 148635                               Transit Car Cleaner          0.00
# 148636                                   General Laborer          0.00
# 148637                               Arborist Technician          0.00
# 148638                            Transit Fare Inspector          0.00
# 148639                                       Electrician          0.00
# 148640                                         Custodian          0.00
# 148641                           Parking Control Officer          0.00
# 148642                                      Museum Guard          0.00
# 148643                                       Sign Worker          0.00
# 148644                           Parking Control Officer          0.00
# 148645                      Stationary Eng, Sewage Plant          0.00
# 148646                         Human Services Technician          0.00
# 148647                                      Not provided  Not Provided
# 148648                       Communications Dispatcher 2          0.00
# 148649                                         Custodian          0.00
# 148650                                         Custodian          0.00
# 148651                                      Not provided  Not Provided
# 148652                                      Not provided  Not Provided
# 148653                                      Not provided  Not Provided
# 148654                        Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# Id
# 1                  0        400184           NaN  567595.43         567595.43
# 2             245132        137811           NaN  538909.28         538909.28
# 3             106088       16452.6           NaN  335279.91         335279.91
# 4            56120.7        198307           NaN  332343.61         332343.61
# 5               9737        182235           NaN  326373.19         326373.19
# 6               8601        189083           NaN  316285.74         316285.74
# 7            89062.9        134426           NaN  315981.05         315981.05
# 8                  0       51322.5           NaN  307899.46         307899.46
# 9            86362.7       40132.2           NaN  303427.55         303427.55
# 10                 0       17115.7           NaN  302377.73         302377.73
# 11           71344.9       33149.9           NaN  299494.17         299494.17
# 12           87082.6        110804           NaN  297608.92         297608.92
# IS TRAINER - SENIOR                                      1
# CHIEF TELEPHONE OPERATOR                                 1
# CEMENT FINISHER SUPERVISOR II                            1
# EXECUTIVE DIRECTOR, SOUTHEAST COMMUNITY FACILITY         1
# Marina Associate Manager                                 1
# ELECTRIC MOTOR REPAIR SUPERVISOR I                       1
# MAYOR'S PROGRAM MANAGER                                  1
# HEAD AIRPORT ELECTRICIAN                                 1
# PIANIST                                                  1
# TRAF SIGNAL ELECTRICIAN SUP II                           1
# HEAVY EQUIPMENT OPERATIONS ASSISTANT SUPERVISOR          1
# PAINTER SUPERVISOR II                                    1
# COURT REPORTER COORDINATOR                               1
# Special Assistant 13                                     1
# Public Service Aide-Technical                            1
# CONFIDENTIAL SECRETARY CITY ATTORNEY                     1
# SENIOR SUPERVISING PROBATION OFFICER, JUVENILE POU       1
# SECRETARY, LIBRARY COMMISSION                            1
# CASHIER III                                              1
# POWER PLANT SUPERVISOR I                                 1
# ORNAMENTAL IRON WORKER SUPERVISOR I                      1
# Captain, (Fire Department)                               1
# PUBLIC SAFETY COMMUNICATIONS TECHNICIAN                  1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 12 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148049 non-null object
# OvertimePay         148654 non-null object
# OtherPay            148654 non-null object
# Benefits            112495 non-null object
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Agency              148654 non-null object
# Status              38119 non-null object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 13.6+ MB

# %%
for col in ['BasePay', 'OvertimePay', 'OtherPay', 'Benefits']:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 12 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Agency              148654 non-null object
# Status              38119 non-null object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 13.6+ MB

# %% [markdown]
# What is the average BasePay ?

# %%
data['BasePay'].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# ### What is the highest amount of OvertimePay in the dataset ?

# %%
data['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# ### What is the job title and totalpay benefits of JOSEPH DRISCOLL ?

# %%
data[data['EmployeeName'] == 'JOSEPH DRISCOLL'][['JobTitle','TotalPayBenefits']]
# Out:
#                      JobTitle  TotalPayBenefits
# 24  CAPTAIN, FIRE SUPPRESSION         270324.91

# %% [markdown]
# ### What is the name of highest paid person (including benefits)?

# %%
data.iloc[data['TotalPayBenefits'].idxmax()]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                     167411
# OvertimePay                                                      0
# OtherPay                                                    400184
# Benefits                                                       NaN
# TotalPay                                                    567595
# TotalPayBenefits                                            567595
# Year                                                          2011
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %% [markdown]
# ### What was the average (mean) BasePay of all employees per year? (2011-2014) ?

# %%
data.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ### How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?)

# %%
sum(data[data['Year'] == 2013]['JobTitle'].value_counts() == 1)
# Out:
# 202

# %% [markdown]
# ### How many people have the word Chief in their job title?

# %%
sum(data['JobTitle'].str.lower().str.contains('chief', na=False))
# Out:
# 627
